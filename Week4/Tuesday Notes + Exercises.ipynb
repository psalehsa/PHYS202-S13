# %% [markdown]
# 3D Plotting and Functions
# =========================

# %% [markdown]
# The dipole potential is just the cum of the potentials from two point charges separated by some distance. We'll consider a pair of point charges +- located at x = 0, y = +- d.
#
#
# $ V(x,y)=\frac{kq}{\sqrt{x^2+(y-d)^2}}-\frac{kq}{\sqrt{x^2+(y+d)^2}}$
#
# Recall that k=1/4$\pi$ epsilon_0. To see what is happening we will just let q=1 and d = 1. The answer won't depend in an important way on these choices.

# %%
#make the x-y grid to cover the plane -2<x<2 and -2<y<2.
dx=.06 #steps of .06
dy=.06
x=arange(-2.,2.,dx)
y=arange(-2.,2.,dy)
X,Y=meshgrid(x,y)
#make the function, V(x,y)
k=1; q=1; d=1
V=(k*q/(X**2+(Y-d)**2)**(1/2.))- (k*q/(X**2+(Y+d)**2)**(1/2.))
print V
# Out:
# [[-0.1698635  -0.17826925 -0.18715865 ..., -0.19336737 -0.18414007
#   -0.17541494]
#  [-0.17127992 -0.17998007 -0.18920149 ..., -0.19565471 -0.18606779
#   -0.17702367]
#  [-0.17245961 -0.18144664 -0.19099347 ..., -0.19768747 -0.18774672
#   -0.17839056]
#  ...,
#  [ 0.17310174  0.18227437  0.19203282 ...,  0.19888408  0.18871243
#    0.17915368]
#  [ 0.17209427  0.1809867   0.19042599 ...,  0.19704029  0.18721662
#    0.1779635 ]
#  [ 0.17083282  0.17943553  0.18854686 ...,  0.19491887  0.18545135
#    0.17651294]]

# %%
from mpl_toolkits.mplot3d import Axes3D
fig=figure()
ax=fig.gca(projection='3d')
p=ax.plot_surface(X,Y,V,rstride=1,cstride=1,linewidth=0,cmap=cm.gist_earth_r)
cb=fig.colorbar(p,shrink=0.5)

# %%
#Represent 3D data by contours
levels = array([8,4,2,1,0.5,0.25,0,-0.25,-0.5,-1,-2,-4,-8])
contour(X,Y,V,levels,cmap=cm.coolwarm)
show()

# %% [markdown]
#  EX.1 Make a 3-D plot of the function
# $G(x,y)=e^{-x^2-y^2}$ over the range -6 < (x,y) < 6 using 51 bins in $x$ and 51 bines in $y$.

# %%
dx=12./51.
dy=12./51.
x=arange(-6.,6.,dx)
y=arange(-6.,6.,dy)
X,Y=meshgrid(x,y)
G=e**(-X**2-Y**2)
fig=figure()
ax=fig.gca(projection='3d')
p=ax.plot_surface(X,Y,G,rstride=1, cstride=1, linewidth=0, cmap=cm.gist_earth_r)
cb=fig.colorbar(p,shrink=0.5)
cset=ax.contour(X,Y,G,array([0.,0.2,0.4,0.6,0.8]),zdir='x',offset=-6.,cmap=cm.gist_earth_r)

# %% [markdown]
# Ex 2: Determine the electric potential for a quadrupole consisting of q=-1.0 nC at both (x= +- 2, y=0), and q=+1.0 nC at both (x=0,y=+-2). Make a surface plot and a contour plot on the range $-4 < x,y < 4$     using 101 bins in x and 101 bins in y. What is the value of the function V(20,30)?

# %%
dx= 8./101.
dy=8./101.
x=arange(-4.,4.,dx)
y=arange(-4.,4.,dy)
X,Y=meshgrid(x,y)

k=8987551787 #Nm^2/C^2
q1=-10**(-9) #C
q2=10**(-9) #C
d= 2 #m
V=((k*q1/(X**2+(Y-d)**2)**(1/2.))- (k*q1/(Y**2+(X+d)**2)**(1/2.)))+((k*q2/(X**2+(Y+d)**2)**(1/2.))- (k*q2/(Y**2+(X-d)**2)**(1/2.)))
fig=figure()
ax=fig.gca(projection='3d')
p=ax.plot_surface(X,Y,V,rstride=1,cstride=1,linewidth=0,cmap=cm.gist_earth_r)
cb=fig.colorbar(p,shrink=0.5)

# %%
levels = array([8,4,2,1,0.5,0.25,0,-0.25,-0.5,-1,-2,-4,-8])
contour(X,Y,V,levels,cmap=cm.coolwarm)
show()

# %% [markdown]
# Ex 3: Now we want to refractor the code we wrote in the example and first exercise to make it more useful. In this exercise you will encapsulate your electric potential calcuations within functions.

# %% [markdown]
# a)

# %%
def pointPotential(x,y,q,posx,posy):
    k=8987551787
    Vxy= (k*q)/((((x-posx)**(2.))+((y-posy)**(2.)))**(1/2.))
    """Takes as arguements the point or points in space where you want to know the potential, the size(and sign) of the charge q and the position of the charge in the plane, and return the electric potential"""
    return Vxy

# %%
x=1; y=1.
V11=pointPotential(x,y,1e-9,0,0.)
print V11
# Out:
# 6.35515881485

# %%
x,y=meshgrid(arange(-2.,2.,0.06),arange(-2.,2.,0.06))
Vxy=pointPotential(x,y,1e-9,0,0.)
print Vxy
# Out:
# [[ 3.17757941  3.22559495  3.27428945 ...,  3.30710904  3.25798498
#    3.20951244]
#  [ 3.22559495  3.27585506  3.32689793 ...,  3.36134185  3.30979899
#    3.25901295]
#  [ 3.27428945  3.32689793  3.38040362 ...,  3.41655455  3.36247083
#    3.30926047]
#  ...,
#  [ 3.30710904  3.36134185  3.41655455 ...,  3.45389066  3.3980434
#    3.3431539 ]
#  [ 3.25798498  3.30979899  3.36247083 ...,  3.3980434   3.34482043
#    3.29243067]
#  [ 3.20951244  3.25901295  3.30926047 ...,  3.3431539   3.29243067
#    3.24242797]]

# %% [markdown]
# b)

# %%
def dipolePotential(x,y,q,d):
    k=8987551787
    Vxy=(k*q/(x**2+(y-d)**2)**(1/2.))- (k*q/(x**2+(y+d)**2)**(1/2.))

    """Takes as arguements the point or points you want to know the potential, the size of the charges q, and the distince d that seperates the charges."""
    return Vxy

# %% [markdown]
# c)

# %%
dx=.06 #steps of .06
dy=.06
x=arange(-2.,2.,dx)
y=arange(-2.,2.,dy)
X,Y=meshgrid(x,y)
v=dipolePotential(x,y,1.,1.)
from mpl_toolkits.mplot3d import Axes3D
fig=figure()
ax=fig.gca(projection='3d')
p=ax.plot_surface(X,Y,v,rstride=1,cstride=1,linewidth=0,cmap=cm.gist_earth_r)
cb=fig.colorbar(p,shrink=0.5)

# %%
dx= 8./101.
dy=8./101.
x=arange(-4.,4.,dx)
y=arange(-4.,4.,dy)
X,Y=meshgrid(x,y)

k=8987551787 #Nm^2/C^2
q1=-10**(-9) #C
q2=10**(-9) #C
d= 2 #m
V=dipolePotential(X,Y,q1,d)+dipolePotential(Y,X,q2,-d)
#V=((k*q1/(X**2+(Y-d)**2)**(1/2.))- (k*q1/(Y**2+(X+d)**2)**(1/2.)))+((k*q2/(X**2+(Y+d)**2)**(1/2.))- (k*q2/(Y**2+(X-d)**2)**(1/2.)))
fig=figure()
ax=fig.gca(projection='3d')
p=ax.plot_surface(X,Y,V,rstride=1,cstride=1,linewidth=0,cmap=cm.gist_earth_r)
cb=fig.colorbar(p,shrink=0.5)
